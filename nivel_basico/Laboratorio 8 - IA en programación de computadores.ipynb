# %% [markdown]
# # Juego adivina el número

# %%
#juego de adivinar el número
import random

# %%
def generar_numero():
  return random.randint(1,100)

# %%
def juego_adivinar():
  numero_secreto = generar_numero()
  intentos = 0

  print("Bienvenido al juego de adivinar el número!")
  print("Tienes que adivinar un número entre 1 y 100.")

  while True:
    try:
      intento = int(input("Adivina el numero: "))
      intentos += 1

      if intento < numero_secreto:
        print("El número es mayor. intenta de nuevo")
      elif intento > numero_secreto:
        print("El número es menor. intenta de nuevo")
      else:
        print(f"¡Felicidades! Adivinaste el número {numero_secreto} en {intentos} intentos.")
        break
    except ValueError:
      print("Por favor, ingresa un número válido.")

# %%
juego_adivinar()
# Out:
# Bienvenido al juego de adivinar el número!
# Tienes que adivinar un número entre 1 y 100.
# Adivina el numero:  25
# El número es mayor. intenta de nuevo
# Adivina el numero:  50
# El número es menor. intenta de nuevo
# Adivina el numero:  40
# El número es mayor. intenta de nuevo
# Adivina el numero:  45
# El número es menor. intenta de nuevo
# Adivina el numero:  42
# El número es menor. intenta de nuevo
# Adivina el numero:  41
# ¡Felicidades! Adivinaste el número 41 en 6 intentos.

# %% [markdown]
# # Calculadora

# %%
#calculadora de operaciones basicas

def suma(a,b):
    return a + b

def resta(a,b):
    return a - b

def multiplicacion(a,b):
    return a * b

def division(a,b):

    if b != 0:
        return a / b
    else:
        return "No se puede dividir por cero"

# %%
while True:
  print("*****Calculadora*****")
  print("* 1. Suma           *")
  print("* 2. Resta          *")
  print("* 3. Multiplicación *")
  print("* 4. División       *")
  print("* 5. Salir          *")
  print("*********************")


  opcion = input("Selecciona una operación: ")

  if opcion == '5':
    print("¡Hasta luego!")
    break

  try:
      num1 = float(input("Ingresa el primer número: "))
      num2 = float(input("Ingresa el segundo número: "))

      if opcion == '1':
        resultado = suma(num1,num2)
        print(f"El resultado de la suma es: {resultado}")
      elif opcion == '2':
        resultado = resta(num1,num2)
        print(f"El resultado de la resta es: {resultado}")
      elif opcion == '3':
        resultado = multiplicacion(num1,num2)
        print(f"El resultado de la multiplicación es: {resultado}")
      elif opcion == '4':
        resultado = division(num1,num2)
        print(f"El resultado de la división es: {resultado}")
      else:
        print("Opción inválida. Por favor, selecciona una opción válida.")
  except ValueError:
      print("Por favor, ingresa números válidos.")
      continue
# Out:
# *****Calculadora*****
# * 1. Suma           *
# * 2. Resta          *
# * 3. Multiplicación *
# * 4. División       *
# * 5. Salir          *
# *********************
# El resultado de la suma es: 6.0
# *****Calculadora*****
# * 1. Suma           *
# * 2. Resta          *
# * 3. Multiplicación *
# * 4. División       *
# * 5. Salir          *
# *********************
# ¡Hasta luego!

# %% [markdown]
# # lista de tarea

# %%
#lista de tareas
lista_tareas = []

# %%
def agregar_tarea(tarea):
    lista_tareas.append(tarea)
    print(f"Tarea '{tarea}' agregada a la lista.")

def eliminar_tarea(indice):
  try:
    tarea = lista_tareas.pop(indice)
    print(f"Tarea '{tarea}' eliminada de la lista.")
  except IndexError:
    print("Índice inválido. No se pudo eliminar la tarea.")

def mostrar_tareas():
    if not lista_tareas:
        print("La lista de tareas está vacía.")
    else:
        print("Lista de tareas:")
        for i,tarea in enumerate(lista_tareas):
            print(f"-{i +1}. {tarea}")

# %%
while True:
    print("*******--Menú--********")
    print("* 1. Agregar tarea    *")
    print("* 2. Eliminar tarea   *")
    print("* 3. Mostrar tareas   *")
    print("* 4. Salir            *")
    print("***********************")
    print()


    opcion = input("Selecciona una opción: ")
    print()

    if opcion == '1':
        tarea = input("Ingresa la tarea que deseas agregar: ")
        agregar_tarea(tarea)
        print()

    elif opcion == '2':
        mostrar_tareas()
        if not lista_tareas:
            print("No hay tareas para eliminar.")
            continue
        elif lista_tareas:
            indice = int(input("Ingresa el número de la tarea que deseas eliminar: "))
            eliminar_tarea(indice - 1)
            print()

    elif opcion == '3':
        mostrar_tareas()
        print()

    elif opcion == '4':
        print("¡Hasta luego!")
        break
        print()

    else:
        print("Opción inválida. Por favor, selecciona una opción válida.")
# Out:
# *******--Menú--********
# * 1. Agregar tarea    *
# * 2. Eliminar tarea   *
# * 3. Mostrar tareas   *
# * 4. Salir            *
# ***********************
#
# Selecciona una opción: 1
#
# Ingresa la tarea que deseas agregar: bañarse
# Tarea 'bañarse' agregada a la lista.
#
# *******--Menú--********
# * 1. Agregar tarea    *
# * 2. Eliminar tarea   *
# * 3. Mostrar tareas   *
# * 4. Salir            *
# ***********************
#
# Selecciona una opción: 2
#
# Lista de tareas:
# -1. Hacer las compras
# -2. ir a trabajar
# -3. hacer ejercicio
# -4. hacer ejercicio
# -5. dormir
# -6. bañarse
# Ingresa el número de la tarea que deseas eliminar: 6
# Tarea 'bañarse' eliminada de la lista.
#
# *******--Menú--********
# * 1. Agregar tarea    *
# * 2. Eliminar tarea   *
# * 3. Mostrar tareas   *
# * 4. Salir            *
# ***********************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-29-3984253294.py in <cell line: 0>()
#       9
#      10
# ---> 11     opcion = input("Selecciona una opción: ")
#      12     print()
#      13
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
